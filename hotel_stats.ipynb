# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"data_hotel.csv")

# %%
dataset
# Out:
#       Unnamed: 0                                              name       city  \
# 0              0                                The Park Hyderabad  Hyderabad
# 1              1                    The Westin Hyderabad Mindspace  Hyderabad
# 2              2                   Courtyard by Marriott Hyderabad  Hyderabad
# 3              3                   Courtyard by Marriott Hyderabad  Hyderabad
# 4              4  Radisson Blu Plaza Hotel Hyderabad Banjara Hills  Hyderabad
# ...          ...                                               ...        ...
# 5337        5337                        OYO 4161 Hotel Shailly Inn  Ahmedabad
# 5338        5338                            OYO 11427 Hotel Kalyan  Ahmedabad
# 5339        5339                                      Hotel Aagman  Ahmedabad
# 5340        5340                               OYO 27638 Jay Radhe  Ahmedabad
# 5341        5341                               OYO 27638 Jay Radhe  Ahmedabad
#
#      Check_in_date Check_out_date  Rating Review  Distance_to_city_center(km)  \
# 0       12/02/2021     14/02/2021     NaN    NaN                          4.0
# 1       12/02/2021     14/02/2021     NaN    NaN                          9.9
# 2       12/02/2021     14/02/2021     NaN    NaN                          4.7
# 3       12/02/2021     14/02/2021     NaN    NaN                          4.7
# 4       12/02/2021     14/02/2021     7.6   Good                          4.5
# ...            ...            ...     ...    ...                          ...
# 5337    12/02/2021     20/02/2021     NaN    NaN                          4.9
# 5338    12/02/2021     20/02/2021     NaN    NaN                          1.6
# 5339    12/02/2021     20/02/2021     NaN    NaN                         77.0
# 5340    12/02/2021     20/02/2021     NaN    NaN                         11.0
# 5341    12/02/2021     20/02/2021     NaN    NaN                         11.0
#
#       Distance_to_Airpot(km) pool  ... free_parking bathtub restuarant  \
# 0                       20.0  yes  ...          yes      no        yes
# 1                       22.0  yes  ...          yes      no        yes
# 2                       21.0  yes  ...          yes      no        yes
# 3                       21.0  yes  ...          yes      no        yes
# 4                       20.0  yes  ...          yes      no        yes
# ...                      ...  ...  ...          ...     ...        ...
# 5337                     9.7   no  ...          yes     yes         no
# 5338                     8.0   no  ...           no     yes         no
# 5339                    77.0   no  ...          yes      no         no
# 5340                    16.0   no  ...           no     yes         no
# 5341                    16.0   no  ...           no     yes         no
#
#      Airport_transfer Bar Kitchen Connecting_rooms_available Internet_access  \
# 0                 yes  no      no                         no              no
# 1                 yes  no      no                         no              no
# 2                 yes  no      no                         no              no
# 3                 yes  no      no                         no              no
# 4                 yes  no      no                         no              no
# ...               ...  ..     ...                        ...             ...
# 5337               no  no      no                         no              no
# 5338               no  no      no                         no              no
# 5339               no  no      no                         no              no
# 5340               no  no      no                         no              no
# 5341               no  no      no                         no              no
#
#      Pet_friendly  PRICE
# 0              no   5040
# 1              no   7800
# 2              no   6700
# 3              no   6700
# 4              no   6375
# ...           ...    ...
# 5337           no  46349
# 5338           no   8793
# 5339           no   5396
# 5340           no   6950
# 5341           no   6950
#
# [5342 rows x 22 columns]

# %%
dataset.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
dataset.isnull().any()
# Out:
# name                           False
# city                           False
# Check_in_date                  False
# Check_out_date                 False
# Rating                          True
# Review                          True
# Distance_to_city_center(km)     True
# Distance_to_Airpot(km)          True
# pool                           False
# gym                            False
# spa                            False
# free_parking                   False
# bathtub                        False
# restuarant                     False
# Airport_transfer               False
# Bar                            False
# Kitchen                        False
# Connecting_rooms_available     False
# Internet_access                False
# Pet_friendly                   False
# PRICE                          False
# dtype: bool

# %%
dataset.dtypes
# Out:
# name                            object
# city                            object
# Check_in_date                   object
# Check_out_date                  object
# Rating                         float64
# Review                          object
# Distance_to_city_center(km)    float64
# Distance_to_Airpot(km)         float64
# pool                            object
# gym                             object
# spa                             object
# free_parking                    object
# bathtub                         object
# restuarant                      object
# Airport_transfer                object
# Bar                             object
# Kitchen                         object
# Connecting_rooms_available      object
# Internet_access                 object
# Pet_friendly                    object
# PRICE                            int64
# dtype: object

# %% [markdown]
# # 1. Handle Missing values

# %%
dataset.median()
# Out:
# Rating                            9.0
# Distance_to_city_center(km)       8.2
# Distance_to_Airpot(km)           10.0
# PRICE                          9397.5
# dtype: float64

# %%
dataset.fillna(dataset.median(),inplace=True)

# %%
dataset.fillna(dataset.mode(),inplace=True)

# %%
dataset.isnull().any()
# Out:
# name                           False
# city                           False
# Check_in_date                  False
# Check_out_date                 False
# Rating                         False
# Review                          True
# Distance_to_city_center(km)    False
# Distance_to_Airpot(km)         False
# pool                           False
# gym                            False
# spa                            False
# free_parking                   False
# bathtub                        False
# restuarant                     False
# Airport_transfer               False
# Bar                            False
# Kitchen                        False
# Connecting_rooms_available     False
# Internet_access                False
# Pet_friendly                   False
# PRICE                          False
# dtype: bool

# %%
dataset["Review"].unique()
# Out:
# array(['Good', nan, 'Exceptional', 'Superb', 'Fabulous', 'Very', '2.0\n2',
#        '4.0\n1', '5.0\n2', '2.0\n1', '4.0\n3', '5.6\n4', '3.0\n4',
#        '4.0\n2', '2.6\n3', '5.4\n10', '4.8\n5', '3.6\n4', '4.6\n3',
#        '5.8\n7', '3.4\n3', '5.4\n3', '5.2\n5', '4.0\n4', '5.0\n4'],
#       dtype=object)

# %%
dataset.hist(figsize=(10,10))
plt.show()

# %% [markdown]
# # divide data into numerical and categorical type

# %%
num=[]

# %%
for col in dataset.columns:
    if(dataset[col].dtype!="object"):
          num.append(col)

# %%
dataset_num=dataset[num]

# %%
plt.figure(figsize=(15,15))
for i,col in enumerate(dataset_num.columns,1):
    plt.subplot(2,2,i)
    sns.boxplot(dataset_num[col])

# %%
plt.figure(figsize=(15,10))
for i,col in enumerate(dataset_num.columns,1):
    plt.subplot(2,2,i)
    sns.distplot(dataset_num[col])
# Out:
# C:\Users\Anjali\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(20,20))

for i,col in enumerate(dataset_num.columns,1):
              plt.subplot(2,2,i)
              sns.violinplot(dataset_num[col])

# %%
cat=[]

# %%
for col in dataset.columns:
    if(dataset[col].dtype=="object"):
          cat.append(col)

# %%
dataset_cat=dataset[cat]

# %%
plt.figure(figsize=(20,32))
for i,col in enumerate(dataset_cat.columns,1):
    plt.subplot(10,2,i)
    sns.countplot(dataset_cat[col])

# %%
plt.figure(figsize=(20,20))

for i,col in enumerate(dataset_cat.columns,1):
              plt.subplot(6,4,i)
              plt.pie(dataset_cat[col].value_counts(),labels=dataset_cat[col].value_counts().index,autopct="%1.f%%")
              plt.title(col)
